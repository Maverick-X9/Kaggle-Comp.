# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter('ignore')

train = pd.read_csv("/kaggle/input/playground-series-s5e5/train.csv")
test = pd.read_csv("/kaggle/input/playground-series-s5e5/test.csv")
submission = pd.read_csv("/kaggle/input/playground-series-s5e5/sample_submission.csv")

# %%
## import libraries
import pandas as pd
import numpy as np
import itertools
from sklearn.preprocessing import LabelEncoder, PolynomialFeatures, StandardScaler

## define feature engineering functions
def add_feature_cross_terms(df, features):
    df = df.copy()
    df = df.loc[:, ~df.columns.duplicated()]  
    for i in range(len(features)):
        for j in range(i + 1, len(features)):
            f1 = features[i]
            f2 = features[j]
            df[f"{f1}_x_{f2}"] = df[f1] * df[f2]
    return df

def add_interaction_features(df, features):
    df_new = df.copy()
    for f1, f2 in itertools.combinations(features, 2):
        df_new[f"{f1}_plus_{f2}"] = df_new[f1] + df_new[f2]
        df_new[f"{f1}_minus_{f2}"] = df_new[f1] - df_new[f2]
        df_new[f"{f2}_minus_{f1}"] = df_new[f2] - df_new[f1]
        df_new[f"{f1}_div_{f2}"] = df_new[f1] / (df_new[f2] + 1e-5)
        df_new[f"{f2}_div_{f1}"] = df_new[f2] / (df_new[f1] + 1e-5)
    return df_new

def add_statistical_features(df, features):
    df_new = df.copy()
    df_new["row_mean"] = df[features].mean(axis=1)
    df_new["row_std"] = df[features].std(axis=1)
    df_new["row_max"] = df[features].max(axis=1)
    df_new["row_min"] = df[features].min(axis=1)
    df_new["row_median"] = df[features].median(axis=1)
    return df_new

## define numerical features
numerical_features = train.select_dtypes(include=[np.number]).columns.tolist()
numerical_features = [col for col in numerical_features if col not in ['id', 'Calories']]

## apply feature engineering
train = add_feature_cross_terms(train, numerical_features)
test = add_feature_cross_terms(test, numerical_features)

train = add_interaction_features(train, numerical_features)
test = add_interaction_features(test, numerical_features)

train = add_statistical_features(train, numerical_features)
test = add_statistical_features(test, numerical_features)

## encode categorical features
le = LabelEncoder()
train['Sex'] = le.fit_transform(train['Sex'])
test['Sex'] = le.transform(test['Sex'])

train['Sex'] = train['Sex'].astype('category')
test['Sex'] = test['Sex'].astype('category')

## add polynomial features
poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
poly_train = poly.fit_transform(train[numerical_features])
poly_test = poly.transform(test[numerical_features])
poly_feature_names = poly.get_feature_names_out(numerical_features)

poly_train_df = pd.DataFrame(poly_train, columns=poly_feature_names)
poly_test_df = pd.DataFrame(poly_test, columns=poly_feature_names)

train = pd.concat([train.reset_index(drop=True), poly_train_df], axis=1)
test = pd.concat([test.reset_index(drop=True), poly_test_df], axis=1)

## define model input and target
X = train.drop(columns=['id', 'Calories'])
y = np.log1p(train['Calories'])  
X_test = test.drop(columns=['id'])

FEATURES = X.columns.tolist()

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_log_error
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
import time

FOLDS = 7
kf = KFold(n_splits=FOLDS, shuffle=True, random_state=42)
models = {
    'CatBoost': CatBoostRegressor(verbose=100, random_seed=42, cat_features=['Sex'], early_stopping_rounds=100),
    'XGBoost': XGBRegressor(max_depth=10, colsample_bytree=0.7, subsample=0.9, n_estimators=2000, learning_rate=0.02,
                            gamma=0.01, max_delta_step=2, early_stopping_rounds=100, eval_metric='rmse',
                            enable_categorical=True, random_state=42),
    'LightGBM': LGBMRegressor(n_estimators=2000, learning_rate=0.02, max_depth=10, colsample_bytree=0.7,
                              subsample=0.9, random_state=42, verbose=-1)
}

results = {name: {'oof': np.zeros(len(train)), 'pred': np.zeros(len(test)), 'rmsle': []} for name in models}

for name, model in models.items():
    print(f"\n=== Training {name} ===")
    for i, (train_idx, valid_idx) in enumerate(kf.split(X, y)):
        print(f"\nFold {i+1}")
        x_train, y_train = X.iloc[train_idx], y[train_idx]
        x_valid, y_valid = X.iloc[valid_idx], y[valid_idx]
        
        x_train = x_train.loc[:, ~x_train.columns.duplicated()]
        x_valid = x_valid.loc[:, ~x_valid.columns.duplicated()]
        x_test = X_test.loc[:, ~X_test.columns.duplicated()].copy()

        start = time.time()
        
        if name == 'XGBoost':
            model.fit(x_train, y_train, eval_set=[(x_valid, y_valid)], verbose=100)
        elif name == 'CatBoost':
            model.fit(x_train, y_train, eval_set=(x_valid, y_valid))
        else:
            model.fit(x_train, y_train)

        oof_pred = model.predict(x_valid)
        test_pred = model.predict(x_test)
        
        results[name]['oof'][valid_idx] = oof_pred
        results[name]['pred'] += test_pred / FOLDS
        
        rmsle = np.sqrt(mean_squared_log_error(np.expm1(y_valid), np.expm1(oof_pred)))
        results[name]['rmsle'].append(rmsle)
        
        print(f"Fold {i+1} RMSLE: {rmsle:.4f}")
        print(f"Training time: {time.time() - start:.1f} sec")


print("\n=== Model Comparison ===")
for name in models:
    mean_rmsle = np.mean(results[name]['rmsle'])
    std_rmsle = np.std(results[name]['rmsle'])
    print(f"{name} - Mean RMSLE: {mean_rmsle:.4f} ± {std_rmsle:.4f}")
# Out:
# === Training CatBoost ===
#
# Fold 1
# Learning rate set to 0.14053
# 0:	learn: 0.8364851	test: 0.8356619	best: 0.8356619 (0)	total: 204ms	remaining: 3m 23s
# 100:	learn: 0.0631319	test: 0.0638931	best: 0.0638931 (100)	total: 12.4s	remaining: 1m 50s
# 200:	learn: 0.0604752	test: 0.0620627	best: 0.0620627 (200)	total: 25.5s	remaining: 1m 41s
# 300:	learn: 0.0590925	test: 0.0612550	best: 0.0612550 (300)	total: 38s	remaining: 1m 28s
# 400:	learn: 0.0582505	test: 0.0608786	best: 0.0608786 (400)	total: 50.6s	remaining: 1m 15s
# 500:	learn: 0.0576006	test: 0.0606443	best: 0.0606397 (497)	total: 1m 2s	remaining: 1m 2s
# 600:	learn: 0.0570770	test: 0.0605160	best: 0.0605160 (600)	total: 1m 15s	remaining: 49.9s
# 700:	learn: 0.0566363	test: 0.0604217	best: 0.0604215 (694)	total: 1m 27s	remaining: 37.3s
# 800:	learn: 0.0562358	test: 0.0603571	best: 0.0603571 (800)	total: 1m 39s	remaining: 24.7s
# 900:	learn: 0.0558598	test: 0.0602745	best: 0.0602745 (900)	total: 1m 51s	remaining: 12.2s
# 999:	learn: 0.0555258	test: 0.0602001	best: 0.0602001 (999)	total: 2m 3s	remaining: 0us
#
# bestTest = 0.06020007613
# bestIteration = 999
#
# Fold 1 RMSLE: 0.0602
# Training time: 126.4 sec
#
# Fold 2
# Learning rate set to 0.14053
# 0:	learn: 0.8364342	test: 0.8402843	best: 0.8402843 (0)	total: 160ms	remaining: 2m 39s
# 100:	learn: 0.0629566	test: 0.0642383	best: 0.0642383 (100)	total: 12.4s	remaining: 1m 50s
# 200:	learn: 0.0601835	test: 0.0621418	best: 0.0621418 (200)	total: 25.5s	remaining: 1m 41s
# 300:	learn: 0.0589341	test: 0.0612855	best: 0.0612855 (300)	total: 38s	remaining: 1m 28s
# 400:	learn: 0.0581641	test: 0.0609215	best: 0.0609189 (393)	total: 50.1s	remaining: 1m 14s
# 500:	learn: 0.0575539	test: 0.0606602	best: 0.0606602 (500)	total: 1m 2s	remaining: 1m 2s
# 600:	learn: 0.0570419	test: 0.0605134	best: 0.0605112 (598)	total: 1m 14s	remaining: 49.5s
# 700:	learn: 0.0566006	test: 0.0604271	best: 0.0604199 (694)	total: 1m 27s	remaining: 37.1s
# 800:	learn: 0.0562149	test: 0.0603659	best: 0.0603555 (794)	total: 1m 38s	remaining: 24.6s
# 900:	learn: 0.0558554	test: 0.0603442	best: 0.0603432 (892)	total: 1m 50s	remaining: 12.1s
# 999:	learn: 0.0554974	test: 0.0602726	best: 0.0602724 (993)	total: 2m 2s	remaining: 0us
#
# bestTest = 0.06027237125
# bestIteration = 993
#
# Shrink model to first 994 iterations.
# Fold 2 RMSLE: 0.0603
# Training time: 125.6 sec
#
# Fold 3
# Learning rate set to 0.14053
# 0:	learn: 0.8374009	test: 0.8359668	best: 0.8359668 (0)	total: 170ms	remaining: 2m 49s
# 100:	learn: 0.0631776	test: 0.0642890	best: 0.0642890 (100)	total: 12.6s	remaining: 1m 52s
# 200:	learn: 0.0603061	test: 0.0618179	best: 0.0618179 (200)	total: 25.8s	remaining: 1m 42s
# 300:	learn: 0.0590204	test: 0.0609043	best: 0.0609043 (300)	total: 38.2s	remaining: 1m 28s
# 400:	learn: 0.0581926	test: 0.0605383	best: 0.0605383 (400)	total: 50.2s	remaining: 1m 14s
# 500:	learn: 0.0575200	test: 0.0602595	best: 0.0602595 (500)	total: 1m 3s	remaining: 1m 2s
# 600:	learn: 0.0570494	test: 0.0601284	best: 0.0601256 (591)	total: 1m 14s	remaining: 49.8s
# 700:	learn: 0.0566165	test: 0.0600245	best: 0.0600223 (699)	total: 1m 27s	remaining: 37.5s
# 800:	learn: 0.0562197	test: 0.0599466	best: 0.0599422 (799)	total: 1m 39s	remaining: 24.8s
# 900:	learn: 0.0558673	test: 0.0599034	best: 0.0599027 (896)	total: 1m 51s	remaining: 12.3s
# 999:	learn: 0.0555356	test: 0.0599154	best: 0.0598959 (919)	total: 2m 4s	remaining: 0us
#
# bestTest = 0.05989588118
# bestIteration = 919
#
# Shrink model to first 920 iterations.
# Fold 3 RMSLE: 0.0599
# Training time: 127.1 sec
#
# Fold 4
# Learning rate set to 0.14053
# 0:	learn: 0.8372251	test: 0.8372236	best: 0.8372236 (0)	total: 179ms	remaining: 2m 58s
# 100:	learn: 0.0633993	test: 0.0636652	best: 0.0636652 (100)	total: 12.5s	remaining: 1m 51s
# 200:	learn: 0.0604580	test: 0.0612674	best: 0.0612674 (200)	total: 25.4s	remaining: 1m 40s
# 300:	learn: 0.0591846	test: 0.0604768	best: 0.0604720 (298)	total: 37.9s	remaining: 1m 28s
# 400:	learn: 0.0583996	test: 0.0600451	best: 0.0600451 (400)	total: 49.8s	remaining: 1m 14s
# 500:	learn: 0.0577599	test: 0.0598155	best: 0.0598155 (500)	total: 1m 2s	remaining: 1m 2s
# 600:	learn: 0.0572723	test: 0.0596004	best: 0.0595996 (599)	total: 1m 13s	remaining: 49s
# 700:	learn: 0.0568239	test: 0.0595034	best: 0.0595034 (700)	total: 1m 25s	remaining: 36.6s
# 800:	learn: 0.0564402	test: 0.0593877	best: 0.0593859 (798)	total: 1m 38s	remaining: 24.4s
# 900:	learn: 0.0560690	test: 0.0593147	best: 0.0593132 (893)	total: 1m 49s	remaining: 12s
# 999:	learn: 0.0557233	test: 0.0592435	best: 0.0592435 (999)	total: 2m 2s	remaining: 0us
#
# bestTest = 0.05924349477
# bestIteration = 999
#
# Fold 4 RMSLE: 0.0592
# Training time: 125.0 sec
#
# Fold 5
# Learning rate set to 0.14053
# 0:	learn: 0.8363896	test: 0.8366616	best: 0.8366616 (0)	total: 154ms	remaining: 2m 33s
# 100:	learn: 0.0631251	test: 0.0639139	best: 0.0639139 (100)	total: 12.7s	remaining: 1m 53s
# 200:	learn: 0.0603917	test: 0.0616981	best: 0.0616981 (200)	total: 25.4s	remaining: 1m 40s
# 300:	learn: 0.0591270	test: 0.0609659	best: 0.0609654 (299)	total: 38.2s	remaining: 1m 28s
# 400:	learn: 0.0582863	test: 0.0605398	best: 0.0605398 (400)	total: 50.2s	remaining: 1m 15s
# 500:	learn: 0.0576601	test: 0.0603381	best: 0.0603381 (500)	total: 1m 3s	remaining: 1m 2s
# 600:	learn: 0.0571254	test: 0.0601949	best: 0.0601915 (596)	total: 1m 15s	remaining: 49.9s
# 700:	learn: 0.0566339	test: 0.0600532	best: 0.0600517 (699)	total: 1m 27s	remaining: 37.3s
# 800:	learn: 0.0562394	test: 0.0599793	best: 0.0599765 (796)	total: 1m 39s	remaining: 24.8s
# 900:	learn: 0.0558824	test: 0.0598899	best: 0.0598886 (899)	total: 1m 51s	remaining: 12.2s
# 999:	learn: 0.0555462	test: 0.0598527	best: 0.0598492 (997)	total: 2m 3s	remaining: 0us
#
# bestTest = 0.05984918297
# bestIteration = 997
#
# Shrink model to first 998 iterations.
# Fold 5 RMSLE: 0.0598
# Training time: 126.4 sec
#
# Fold 6
# Learning rate set to 0.14053
# 0:	learn: 0.8374209	test: 0.8338575	best: 0.8338575 (0)	total: 161ms	remaining: 2m 41s
# 100:	learn: 0.0630216	test: 0.0636578	best: 0.0636578 (100)	total: 12.5s	remaining: 1m 51s
# 200:	learn: 0.0602812	test: 0.0616842	best: 0.0616842 (200)	total: 24.9s	remaining: 1m 39s
# 300:	learn: 0.0589673	test: 0.0608641	best: 0.0608628 (297)	total: 38.2s	remaining: 1m 28s
# 400:	learn: 0.0582104	test: 0.0604660	best: 0.0604660 (400)	total: 50.1s	remaining: 1m 14s
# 500:	learn: 0.0575982	test: 0.0602024	best: 0.0602024 (498)	total: 1m 2s	remaining: 1m 2s
# 600:	learn: 0.0570887	test: 0.0600540	best: 0.0600534 (596)	total: 1m 14s	remaining: 49.5s
# 700:	learn: 0.0566476	test: 0.0599516	best: 0.0599492 (688)	total: 1m 26s	remaining: 36.9s
# 800:	learn: 0.0562417	test: 0.0598684	best: 0.0598658 (797)	total: 1m 39s	remaining: 24.7s
# 900:	learn: 0.0558925	test: 0.0598150	best: 0.0598150 (900)	total: 1m 51s	remaining: 12.2s
# 999:	learn: 0.0555761	test: 0.0598060	best: 0.0597974 (931)	total: 2m 3s	remaining: 0us
#
# bestTest = 0.05979735486
# bestIteration = 931
#
# Shrink model to first 932 iterations.
# Fold 6 RMSLE: 0.0598
# Training time: 126.1 sec
#
# Fold 7
# Learning rate set to 0.14053
# 0:	learn: 0.8364550	test: 0.8381257	best: 0.8381257 (0)	total: 150ms	remaining: 2m 30s
# 100:	learn: 0.0633628	test: 0.0641601	best: 0.0641601 (100)	total: 12.8s	remaining: 1m 53s
# 200:	learn: 0.0603786	test: 0.0617471	best: 0.0617471 (200)	total: 25.3s	remaining: 1m 40s
# 300:	learn: 0.0591505	test: 0.0610784	best: 0.0610784 (300)	total: 38.3s	remaining: 1m 28s
# 400:	learn: 0.0583296	test: 0.0606082	best: 0.0606082 (400)	total: 50.7s	remaining: 1m 15s
# 500:	learn: 0.0577437	test: 0.0603566	best: 0.0603566 (500)	total: 1m 3s	remaining: 1m 3s
# 600:	learn: 0.0572317	test: 0.0601961	best: 0.0601961 (600)	total: 1m 15s	remaining: 50.2s
# 700:	learn: 0.0567754	test: 0.0600767	best: 0.0600749 (692)	total: 1m 27s	remaining: 37.3s
# 800:	learn: 0.0563782	test: 0.0600285	best: 0.0600214 (786)	total: 1m 40s	remaining: 24.9s
# 900:	learn: 0.0560015	test: 0.0599555	best: 0.0599544 (899)	total: 1m 52s	remaining: 12.3s
# 999:	learn: 0.0556643	test: 0.0599170	best: 0.0599129 (997)	total: 2m 4s	remaining: 0us
#
# bestTest = 0.05991289198
# bestIteration = 997
#
# Shrink model to first 998 iterations.
# Fold 7 RMSLE: 0.0599
# Training time: 127.3 sec
#
# === Training XGBoost ===
#
# Fold 1
# [0]	validation_0-rmse:0.94425
# [100]	validation_0-rmse:0.14144
# [200]	validation_0-rmse:0.06236
# [300]	validation_0-rmse:0.05976
# [400]	validation_0-rmse:0.05969
# [500]	validation_0-rmse:0.05971
# [507]	validation_0-rmse:0.05971
# Fold 1 RMSLE: 0.0597
# Training time: 177.5 sec
#
# Fold 2
# [0]	validation_0-rmse:0.94876
# [100]	validation_0-rmse:0.14225
# [200]	validation_0-rmse:0.06290
# [300]	validation_0-rmse:0.06032
# [400]	validation_0-rmse:0.06027
# [460]	validation_0-rmse:0.06028
# Fold 2 RMSLE: 0.0603
# Training time: 167.5 sec
#
# Fold 3
# [0]	validation_0-rmse:0.94356
# [100]	validation_0-rmse:0.14189
# [200]	validation_0-rmse:0.06315
# [300]	validation_0-rmse:0.06053
# [400]	validation_0-rmse:0.06046
# [469]	validation_0-rmse:0.06047
# Fold 3 RMSLE: 0.0604
# Training time: 167.7 sec
#
# Fold 4
# [0]	validation_0-rmse:0.94483
# [100]	validation_0-rmse:0.14106
# [200]	validation_0-rmse:0.06186
# [300]	validation_0-rmse:0.05924
# [400]	validation_0-rmse:0.05914
# [500]	validation_0-rmse:0.05915
# [517]	validation_0-rmse:0.05915
# Fold 4 RMSLE: 0.0591
# Training time: 173.1 sec
#
# Fold 5
# [0]	validation_0-rmse:0.94521
# [100]	validation_0-rmse:0.14043
# [200]	validation_0-rmse:0.06179
# [300]	validation_0-rmse:0.05943
# [400]	validation_0-rmse:0.05939
# [493]	validation_0-rmse:0.05942
# Fold 5 RMSLE: 0.0594
# Training time: 171.0 sec
#
# Fold 6
# [0]	validation_0-rmse:0.94170
# [100]	validation_0-rmse:0.14087
# [200]	validation_0-rmse:0.06261
# [300]	validation_0-rmse:0.06010
# [400]	validation_0-rmse:0.06002
# [500]	validation_0-rmse:0.06004
# [529]	validation_0-rmse:0.06004
# Fold 6 RMSLE: 0.0600
# Training time: 183.3 sec
#
# Fold 7
# [0]	validation_0-rmse:0.94678
# [100]	validation_0-rmse:0.14179
# [200]	validation_0-rmse:0.06244
# [300]	validation_0-rmse:0.05981
# [400]	validation_0-rmse:0.05972
# [500]	validation_0-rmse:0.05973
# [524]	validation_0-rmse:0.05973
# Fold 7 RMSLE: 0.0597
# Training time: 180.4 sec
#
# === Training LightGBM ===
#
# Fold 1
# Fold 1 RMSLE: 0.0601
# Training time: 184.2 sec
#
# Fold 2
# Fold 2 RMSLE: 0.0605
# Training time: 182.7 sec
#
# Fold 3
# Fold 3 RMSLE: 0.0603
# Training time: 182.8 sec
#
# Fold 4
# Fold 4 RMSLE: 0.0594
# Training time: 185.4 sec
#
# Fold 5
# Fold 5 RMSLE: 0.0599
# Training time: 184.8 sec
#
# Fold 6
# Fold 6 RMSLE: 0.0600
# Training time: 186.1 sec
#
# Fold 7
# Fold 7 RMSLE: 0.0597
# Training time: 182.2 sec
#
# === Model Comparison ===
# CatBoost - Mean RMSLE: 0.0599 ± 0.0003
# XGBoost - Mean RMSLE: 0.0598 ± 0.0004
# LightGBM - Mean RMSLE: 0.0600 ± 0.0004

# %%
from scipy.optimize import minimize
from sklearn.metrics import mean_squared_log_error

oof_preds = {name: np.expm1(results[name]['oof']) for name in results}
test_preds = {name: np.expm1(results[name]['pred']) for name in results}
y_true = np.expm1(y)

def rmsle_loss(weights):
    blended = (
        weights[0] * oof_preds['CatBoost'] +
        weights[1] * oof_preds['XGBoost'] +
        weights[2] * oof_preds['LightGBM']
    )
    return np.sqrt(mean_squared_log_error(y_true, blended))

initial_weights = [1/3, 1/3, 1/3]
constraints = ({'type': 'eq', 'fun': lambda w: 1 - sum(w)})
bounds = [(0, 1)] * 3

res = minimize(rmsle_loss, initial_weights, method='SLSQP', bounds=bounds, constraints=constraints)
best_weights = res.x

print(f"\n✅ Optimized Weights:")
print(f"CatBoost = {best_weights[0]:.4f}")
print(f"XGBoost  = {best_weights[1]:.4f}")
print(f"LightGBM = {best_weights[2]:.4f}")

blended_preds = (
    best_weights[0] * test_preds['CatBoost'] +
    best_weights[1] * test_preds['XGBoost'] +
    best_weights[2] * test_preds['LightGBM']
)

blended_preds = np.clip(blended_preds, 1, 314)

submission['Calories'] = blended_preds
submission.to_csv('submission.csv', index=False)

print("\nSubmission Head:")
print(submission.head())

print(f"\nPredict Mean: {blended_preds.mean():.2f}")
print(f"Predict Median: {np.median(blended_preds):.2f}")
# Out:
# ✅ Optimized Weights:
# CatBoost = 0.3333
# XGBoost  = 0.3333
# LightGBM = 0.3333
#
# Submission Head:
#        id    Calories
# 0  750000   27.373531
# 1  750001  107.911065
# 2  750002   87.401171
# 3  750003  125.465561
# 4  750004   75.842446
#
# Predict Mean: 88.17
# Predict Median: 76.42

# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv("/kaggle/input/caloriecast-adaptive-ensemble-engine-for-s5e5/submission.csv")
df2 = pd.read_csv("/kaggle/input/ensemble-of-solutions/submission.csv")
df3 = pd.read_csv("/kaggle/input/ps-s5e5-log-blended-cat-xgboost-with-50-fold-cv/ensemble_submission.csv")


ground_truth = pd.read_csv("/kaggle/input/playground-series-s5e5/sample_submission.csv")  

ground_truth['Calories'] = (0.4 * df1['Calories']) + (0.3 * df2['Calories'])+(.3 * df3['Calories'])
ground_truth.to_csv('submission.csv', index=False)
