# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical

# Preprocessing Functions
def preprocess_data(data_dir, image_size=(128, 128)):
    classes = os.listdir(data_dir)
    class_labels = {cls_name: idx for idx, cls_name in enumerate(classes)}

    images = []
    labels = []

    for cls_name in classes:
        cls_folder = os.path.join(data_dir, cls_name)
        if os.path.isdir(cls_folder):
            for img_file in os.listdir(cls_folder):
                img_path = os.path.join(cls_folder, img_file)
                try:
                    img = cv2.imread(img_path)
                    img = cv2.resize(img, image_size)
                    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                    images.append(img)
                    labels.append(class_labels[cls_name])
                except Exception as e:
                    print(f"Error processing image {img_path}: {e}")

    X = np.array(images, dtype="float32") / 255.0
    y = to_categorical(labels, num_classes=len(classes))

    return X, y

def split_dataset(X, y, test_size=0.2, random_state=42):
    return train_test_split(X, y, test_size=test_size, random_state=random_state)

# Model Building
def build_model(input_shape, num_classes):
    model = models.Sequential([
        layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(128, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(256, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.GlobalAveragePooling2D(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

# Paths to data
train_dir = r"\zz_oral\OA\TRAIN"
test_dir = r"\zz_oral\OA\TEST"

# Preprocess data
image_size = (128, 128)
X_train, y_train = preprocess_data(train_dir, image_size=image_size)
X_test, y_test = preprocess_data(test_dir, image_size=image_size)

# Split training data
X_train, X_val, y_train, y_val = split_dataset(X_train, y_train)

# Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    fill_mode='nearest'
)
datagen.fit(X_train)

# Build and compile the model
input_shape = (image_size[0], image_size[1], 3)
num_classes = y_train.shape[1]

model = build_model(input_shape, num_classes)

optimizer = optimizers.AdamW(learning_rate=1e-3)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Define Callbacks
checkpoint = ModelCheckpoint("best_model.h5", save_best_only=True, monitor='val_accuracy', mode='max')
lr_schedule = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)

# Train the model
history = model.fit(
    datagen.flow(X_train, y_train, batch_size=32),
    validation_data=(X_val, y_val),
    epochs=50,
    callbacks=[checkpoint, lr_schedule]
)

# Evaluate the model
model.load_weights("best_model.h5")
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc * 100:.2f}%")

# Plot Metrics
def plot_metrics(history):
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

plot_metrics(history)

# Save the trained model in Keras format
model.save("oral_disease_classifier.keras")

# Predict on Test Data
def predict_image(model, image_path, image_size=(128, 128), class_labels=None):
    img = cv2.imread(image_path)
    img = cv2.resize(img, image_size)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = np.expand_dims(img / 255.0, axis=0)

    predictions = model.predict(img)
    predicted_class = np.argmax(predictions)

    if class_labels:
        return class_labels[predicted_class], predictions[0]
    return predicted_class, predictions[0]

# Example usage:
class_labels = {0: "Caries", 1: "Gingivitis"}
example_image_path = "\zz_oral\OA\TEST\Caries\caries_0_7_1.jpg"
predicted_class, probabilities = predict_image(model, example_image_path, image_size, class_labels)
print(f"Predicted Class: {predicted_class}")
print(f"Class Probabilities: {probabilities}")
# Out:
# Epoch 1/50
# 38/38 [==============================] - 62s 2s/step - loss: 0.4752 - accuracy: 0.7668 - val_loss: 0.9295 - val_accuracy: 0.5067 - lr: 0.0010
# Epoch 2/50
# C:\Users\Abhinav Sharma\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 38/38 [==============================] - 58s 2s/step - loss: 0.3880 - accuracy: 0.8182 - val_loss: 1.1578 - val_accuracy: 0.5067 - lr: 0.0010
# Epoch 3/50
# 38/38 [==============================] - 58s 2s/step - loss: 0.3837 - accuracy: 0.8359 - val_loss: 1.6500 - val_accuracy: 0.5067 - lr: 0.0010
# Epoch 4/50
# 38/38 [==============================] - ETA: 0s - loss: 0.3373 - accuracy: 0.8493
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 38/38 [==============================] - 58s 2s/step - loss: 0.3373 - accuracy: 0.8493 - val_loss: 1.0150 - val_accuracy: 0.5067 - lr: 0.0010
# Epoch 5/50
# 38/38 [==============================] - 58s 2s/step - loss: 0.3015 - accuracy: 0.8721 - val_loss: 1.9679 - val_accuracy: 0.5067 - lr: 2.0000e-04
# Epoch 6/50
# 38/38 [==============================] - 57s 2s/step - loss: 0.3007 - accuracy: 0.8687 - val_loss: 2.2361 - val_accuracy: 0.5067 - lr: 2.0000e-04
# Epoch 7/50
# 38/38 [==============================] - ETA: 0s - loss: 0.2672 - accuracy: 0.8914
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 38/38 [==============================] - 58s 2s/step - loss: 0.2672 - accuracy: 0.8914 - val_loss: 2.4321 - val_accuracy: 0.5067 - lr: 2.0000e-04
# Epoch 8/50
# 38/38 [==============================] - 58s 2s/step - loss: 0.2649 - accuracy: 0.8864 - val_loss: 2.1415 - val_accuracy: 0.5067 - lr: 4.0000e-05
# Epoch 9/50
# 38/38 [==============================] - 49s 1s/step - loss: 0.2736 - accuracy: 0.8838 - val_loss: 2.0529 - val_accuracy: 0.5067 - lr: 4.0000e-05
# Epoch 10/50
# 38/38 [==============================] - ETA: 0s - loss: 0.2428 - accuracy: 0.9057
# Epoch 10: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 38/38 [==============================] - 45s 1s/step - loss: 0.2428 - accuracy: 0.9057 - val_loss: 1.9068 - val_accuracy: 0.5268 - lr: 4.0000e-05
# Epoch 11/50
# 38/38 [==============================] - 44s 1s/step - loss: 0.2675 - accuracy: 0.8906 - val_loss: 1.6358 - val_accuracy: 0.5805 - lr: 8.0000e-06
# Epoch 12/50
# 38/38 [==============================] - 44s 1s/step - loss: 0.2534 - accuracy: 0.8939 - val_loss: 1.2923 - val_accuracy: 0.6309 - lr: 8.0000e-06
# Epoch 13/50
# 38/38 [==============================] - ETA: 0s - loss: 0.2490 - accuracy: 0.8973
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 38/38 [==============================] - 44s 1s/step - loss: 0.2490 - accuracy: 0.8973 - val_loss: 0.9682 - val_accuracy: 0.6913 - lr: 8.0000e-06
# Epoch 14/50
# 38/38 [==============================] - 44s 1s/step - loss: 0.2472 - accuracy: 0.9040 - val_loss: 0.6562 - val_accuracy: 0.7383 - lr: 1.6000e-06
# Epoch 15/50
# 38/38 [==============================] - 43s 1s/step - loss: 0.2602 - accuracy: 0.9007 - val_loss: 0.4344 - val_accuracy: 0.7953 - lr: 1.6000e-06
# Epoch 16/50
# 38/38 [==============================] - 43s 1s/step - loss: 0.2566 - accuracy: 0.8889 - val_loss: 0.2982 - val_accuracy: 0.8456 - lr: 1.6000e-06
# Epoch 17/50
# 38/38 [==============================] - 44s 1s/step - loss: 0.2628 - accuracy: 0.8855 - val_loss: 0.2310 - val_accuracy: 0.8993 - lr: 1.6000e-06
# Epoch 18/50
# 38/38 [==============================] - 44s 1s/step - loss: 0.2725 - accuracy: 0.8923 - val_loss: 0.2028 - val_accuracy: 0.9195 - lr: 1.6000e-06
# Epoch 19/50
# 38/38 [==============================] - 44s 1s/step - loss: 0.2594 - accuracy: 0.9040 - val_loss: 0.1916 - val_accuracy: 0.9228 - lr: 1.6000e-06
# Epoch 20/50
# 38/38 [==============================] - 44s 1s/step - loss: 0.2766 - accuracy: 0.8847 - val_loss: 0.1904 - val_accuracy: 0.9262 - lr: 1.6000e-06
# Epoch 21/50
# 38/38 [==============================] - 46s 1s/step - loss: 0.2600 - accuracy: 0.8872 - val_loss: 0.1940 - val_accuracy: 0.9396 - lr: 1.6000e-06
# Epoch 22/50
# 38/38 [==============================] - 46s 1s/step - loss: 0.2578 - accuracy: 0.8931 - val_loss: 0.1997 - val_accuracy: 0.9396 - lr: 1.6000e-06
# Epoch 23/50
# 38/38 [==============================] - ETA: 0s - loss: 0.2594 - accuracy: 0.8923
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1e-06.
# 38/38 [==============================] - 45s 1s/step - loss: 0.2594 - accuracy: 0.8923 - val_loss: 0.2050 - val_accuracy: 0.9362 - lr: 1.6000e-06
# Epoch 24/50
# 38/38 [==============================] - 45s 1s/step - loss: 0.2416 - accuracy: 0.9099 - val_loss: 0.2095 - val_accuracy: 0.9329 - lr: 1.0000e-06
# Epoch 25/50
# 38/38 [==============================] - 46s 1s/step - loss: 0.2392 - accuracy: 0.9032 - val_loss: 0.2148 - val_accuracy: 0.9295 - lr: 1.0000e-06
# Epoch 26/50
# 38/38 [==============================] - 44s 1s/step - loss: 0.2749 - accuracy: 0.8855 - val_loss: 0.2178 - val_accuracy: 0.9295 - lr: 1.0000e-06
# Epoch 27/50
# 38/38 [==============================] - 44s 1s/step - loss: 0.2507 - accuracy: 0.8939 - val_loss: 0.2191 - val_accuracy: 0.9295 - lr: 1.0000e-06
# Epoch 28/50
# 38/38 [==============================] - 44s 1s/step - loss: 0.2558 - accuracy: 0.8931 - val_loss: 0.2203 - val_accuracy: 0.9295 - lr: 1.0000e-06
# Epoch 29/50
# 38/38 [==============================] - 44s 1s/step - loss: 0.2380 - accuracy: 0.9091 - val_loss: 0.2211 - val_accuracy: 0.9295 - lr: 1.0000e-06
# Epoch 30/50
# 38/38 [==============================] - 44s 1s/step - loss: 0.2617 - accuracy: 0.8880 - val_loss: 0.2238 - val_accuracy: 0.9295 - lr: 1.0000e-06
# Epoch 31/50
# 38/38 [==============================] - 45s 1s/step - loss: 0.2467 - accuracy: 0.9040 - val_loss: 0.2244 - val_accuracy: 0.9295 - lr: 1.0000e-06
# Epoch 32/50
# 38/38 [==============================] - 44s 1s/step - loss: 0.2600 - accuracy: 0.8897 - val_loss: 0.2261 - val_accuracy: 0.9295 - lr: 1.0000e-06
# Epoch 33/50
# 38/38 [==============================] - 44s 1s/step - loss: 0.2528 - accuracy: 0.8906 - val_loss: 0.2255 - val_accuracy: 0.9295 - lr: 1.0000e-06
# Epoch 34/50
# 38/38 [==============================] - 44s 1s/step - loss: 0.2672 - accuracy: 0.8906 - val_loss: 0.2255 - val_accuracy: 0.9295 - lr: 1.0000e-06
# Epoch 35/50
# 38/38 [==============================] - 45s 1s/step - loss: 0.2618 - accuracy: 0.8897 - val_loss: 0.2264 - val_accuracy: 0.9295 - lr: 1.0000e-06
# Epoch 36/50
# 38/38 [==============================] - 45s 1s/step - loss: 0.2589 - accuracy: 0.8906 - val_loss: 0.2244 - val_accuracy: 0.9295 - lr: 1.0000e-06
# Epoch 37/50
# 38/38 [==============================] - 50s 1s/step - loss: 0.2470 - accuracy: 0.9007 - val_loss: 0.2236 - val_accuracy: 0.9295 - lr: 1.0000e-06
# Epoch 38/50
# 38/38 [==============================] - 45s 1s/step - loss: 0.2603 - accuracy: 0.8931 - val_loss: 0.2265 - val_accuracy: 0.9295 - lr: 1.0000e-06
# Epoch 39/50
# 38/38 [==============================] - 46s 1s/step - loss: 0.2399 - accuracy: 0.9032 - val_loss: 0.2271 - val_accuracy: 0.9262 - lr: 1.0000e-06
# Epoch 40/50
# 38/38 [==============================] - 47s 1s/step - loss: 0.2503 - accuracy: 0.8981 - val_loss: 0.2275 - val_accuracy: 0.9295 - lr: 1.0000e-06
# Epoch 41/50
# 38/38 [==============================] - 47s 1s/step - loss: 0.2674 - accuracy: 0.8914 - val_loss: 0.2281 - val_accuracy: 0.9228 - lr: 1.0000e-06
# Epoch 42/50
# 38/38 [==============================] - 48s 1s/step - loss: 0.2514 - accuracy: 0.8948 - val_loss: 0.2280 - val_accuracy: 0.9228 - lr: 1.0000e-06
# Epoch 43/50
# 38/38 [==============================] - 46s 1s/step - loss: 0.2602 - accuracy: 0.8864 - val_loss: 0.2306 - val_accuracy: 0.9228 - lr: 1.0000e-06
# Epoch 44/50
# 38/38 [==============================] - 46s 1s/step - loss: 0.2483 - accuracy: 0.8973 - val_loss: 0.2296 - val_accuracy: 0.9262 - lr: 1.0000e-06
# Epoch 45/50
# 38/38 [==============================] - 45s 1s/step - loss: 0.2489 - accuracy: 0.9066 - val_loss: 0.2307 - val_accuracy: 0.9228 - lr: 1.0000e-06
# Epoch 46/50
# 38/38 [==============================] - 45s 1s/step - loss: 0.2483 - accuracy: 0.9032 - val_loss: 0.2285 - val_accuracy: 0.9262 - lr: 1.0000e-06
# Epoch 47/50
# 38/38 [==============================] - 45s 1s/step - loss: 0.2436 - accuracy: 0.9091 - val_loss: 0.2295 - val_accuracy: 0.9262 - lr: 1.0000e-06
# Epoch 48/50
# 38/38 [==============================] - 46s 1s/step - loss: 0.2412 - accuracy: 0.8990 - val_loss: 0.2292 - val_accuracy: 0.9262 - lr: 1.0000e-06
# Epoch 49/50
# 38/38 [==============================] - 47s 1s/step - loss: 0.2272 - accuracy: 0.9057 - val_loss: 0.2288 - val_accuracy: 0.9262 - lr: 1.0000e-06
# Epoch 50/50
# 38/38 [==============================] - 45s 1s/step - loss: 0.2545 - accuracy: 0.8931 - val_loss: 0.2275 - val_accuracy: 0.9295 - lr: 1.0000e-06
# 13/13 [==============================] - 3s 216ms/step - loss: 0.2006 - accuracy: 0.9314
# Test Accuracy: 93.14%
# 1/1 [==============================] - 0s 157ms/step
# Predicted Class: Caries
# Class Probabilities: [0.8919697  0.10803038]
